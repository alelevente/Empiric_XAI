# %% [markdown]
# # **ProtoDash explanations**

# %%
from aix360.algorithms.protodash import ProtodashExplainer

import numpy as np
import pandas as pd

# %%
UNDER_EDUCATED_TEST_FEATURES = "../01_data/test/under_educated_features.csv"
COLLEGE_EDUCATED_TEST_FEATURES = "../01_data/test/college_educated_features.csv"
WELL_EDUCATED_TEST_FEATURES = "../01_data/test/well_educated_features.csv"
WHOLE_DATASET = "../01_data/census_labeled_indexed.csv"

# %% [markdown]
# ## **Understanding the data**
#
# In this part, we will check what characterizes the datasets.

# %%
whole_census = pd.read_csv(WHOLE_DATASET, index_col="index")

# %%
M = 10 #number of representative examples

# %%
explainer = ProtodashExplainer()

# %%
under = np.loadtxt(UNDER_EDUCATED_TEST_FEATURES, delimiter=",")
coll = np.loadtxt(COLLEGE_EDUCATED_TEST_FEATURES, delimiter=",")
well = np.loadtxt(WELL_EDUCATED_TEST_FEATURES, delimiter=",")

# %% [markdown]
# ### **Under educated set**

# %%
(w_under, s_under, _) = explainer.explain(under, under, M)

# %%
w_under = np.around(w_under/np.sum(w_under), 2)
w_under, s_under
# Out:
# (array([0.25, 0.14, 0.1 , 0.06, 0.16, 0.07, 0.07, 0.06, 0.05, 0.04]),
#  array([ 355, 1591,  190,  256, 1265, 1084, 1343, 1743, 1584, 1322]))

# %%
#show representative samples
under_human_readable = whole_census[whole_census["education-num"] < 10].iloc[s_under]
under_human_readable
# Out:
#        hours-per-week  age  capital-gain  capital-loss         workclass  \
# index
# 797                40   39             0             0           Private
# 4060                3   19             0             0           Private
# 435                90   49             0             0           Private
# 580                12   90          2964             0  Self-emp-not-inc
# 3355               35   23             0             0           Private
# 2778               30   50          7298             0         Local-gov
# 3530               48   45             0             0           Private
# 4434               60   30             0             0           Private
# 4039               40   55             0             0           Private
# 3478               50   38          5178             0      Self-emp-inc
#
#       education  education-num      marital-status   relationship   race  \
# index
# 797     HS-grad              9  Married-civ-spouse        Husband  White
# 4060    HS-grad              9       Never-married      Own-child  White
# 435     HS-grad              9            Divorced  Not-in-family  White
# 580     HS-grad              9       Never-married  Not-in-family  White
# 3355    HS-grad              9       Never-married      Unmarried  White
# 2778    HS-grad              9  Married-civ-spouse           Wife  White
# 3530    HS-grad              9  Married-civ-spouse        Husband  Black
# 4434    HS-grad              9           Separated  Not-in-family  White
# 4039    HS-grad              9             Widowed      Own-child  White
# 3478    HS-grad              9  Married-civ-spouse        Husband  White
#
#        gender native-country  income         occupation  income-category
# index
# 797      Male  United-States   33091       Craft-repair                1
# 4060     Male  United-States    6900              Sales                0
# 435      Male  United-States   20500   Transport-moving                1
# 580      Male  United-States   18169    Exec-managerial                0
# 3355   Female  United-States    2200      Other-service                0
# 2778   Female  United-States   68502       Adm-clerical                2
# 3530     Male              ?   30368  Machine-op-inspct                1
# 4434     Male  United-States   26650  Handlers-cleaners                1
# 4039   Female  United-States   21800       Adm-clerical                1
# 3478     Male       Portugal   63654    Exec-managerial                2

# %% [markdown]
# ### **College education set**

# %%
(w_coll, s_coll, _) = explainer.explain(coll, coll, M)

# %%
w_coll = np.around(w_coll/np.sum(w_coll), 2)
w_coll, s_coll
# Out:
# (array([0.26, 0.09, 0.09, 0.14, 0.13, 0.1 , 0.07, 0.06, 0.04, 0.02]),
#  array([ 389,  245, 1313,  353,  257, 1111,  493, 1096,  431,  734]))

# %%
#show representative samples
coll_human_readable = whole_census[np.logical_and(
    (whole_census["education-num"] >= 10),
    (whole_census["education-num"] < 13))].iloc[s_coll]
coll_human_readable
# Out:
#        hours-per-week  age  capital-gain  capital-loss         workclass  \
# index
# 1477               36   35             0             0           Private
# 916                98   22             0             0           Private
# 5071                5   70             0             0      Self-emp-inc
# 1351               12   18             0             0           Private
# 959                54   29             0             0           Private
# 4407               40   34             0             0  Self-emp-not-inc
# 1881               32   43             0          1902           Private
# 4347               40   54             0             0         Local-gov
# 1624               45   47             0             0           Private
# 2990               40   23         99999             0         State-gov
#
#           education  education-num      marital-status   relationship   race  \
# index
# 1477      Assoc-voc             11  Married-civ-spouse        Husband  White
# 916    Some-college             10       Never-married      Own-child  White
# 5071   Some-college             10       Never-married  Not-in-family  White
# 1351   Some-college             10       Never-married      Own-child  White
# 959    Some-college             10            Divorced      Unmarried  White
# 4407     Assoc-acdm             12       Never-married  Not-in-family  White
# 1881      Assoc-voc             11  Married-civ-spouse           Wife  White
# 4347      Assoc-voc             11  Married-civ-spouse        Husband  Black
# 1624   Some-college             10             Widowed  Not-in-family  White
# 2990   Some-college             10       Never-married  Not-in-family  Other
#
#        gender native-country  income        occupation  income-category
# index
# 1477     Male  United-States   39902      Adm-clerical                1
# 916      Male  United-States   20000    Prof-specialty                1
# 5071     Male  United-States   44290   Exec-managerial                1
# 1351   Female  United-States    4200     Other-service                0
# 959    Female  United-States   18200             Sales                0
# 4407     Male  United-States   13035      Craft-repair                0
# 1881   Female  United-States   79228      Tech-support                2
# 4347     Male  United-States   32000  Transport-moving                1
# 1624   Female        Germany   41000   Exec-managerial                1
# 2990   Female  United-States   99999   Protective-serv                2

# %% [markdown]
# ### **Well educated set**

# %%
(w_well, s_well, _) = explainer.explain(well, well, M)

# %%
w_well = np.around(w_well/np.sum(w_well), 2)
w_well
# Out:
# array([0.43, 0.2 , 0.06, 0.05, 0.08, 0.05, 0.03, 0.04, 0.03, 0.02])

# %%
#show representative samples
well_human_readable = whole_census[whole_census["education-num"] >= 13].iloc[s_well]
well_human_readable
# Out:
#        hours-per-week  age  capital-gain  capital-loss         workclass  \
# index
# 2334               45   42             0             0           Private
# 550                30   22             0             0           Private
# 3096               72   67         15831             0         Local-gov
# 1731               10   74             0             0           Private
# 2618               50   37             0             0  Self-emp-not-inc
# 2525               40   42             0             0       Federal-gov
# 1642               55   55             0             0           Private
# 3230               50   25          2597             0         State-gov
# 1985               60   41             0          1977      Self-emp-inc
# 2698               27   24             0             0         Local-gov
#
#        education  education-num         marital-status    relationship  \
# index
# 2334   Doctorate             16     Married-civ-spouse         Husband
# 550    Bachelors             13          Never-married   Not-in-family
# 3096     Masters             14          Never-married  Other-relative
# 1731     Masters             14               Divorced   Not-in-family
# 2618   Bachelors             13     Married-civ-spouse            Wife
# 2525   Bachelors             13               Divorced       Own-child
# 1642   Bachelors             13  Married-spouse-absent       Unmarried
# 3230   Bachelors             13          Never-married   Not-in-family
# 1985   Bachelors             13     Married-civ-spouse         Husband
# 2698   Bachelors             13          Never-married       Own-child
#
#                      race  gender native-country  income       occupation  \
# index
# 2334                White    Male  United-States   99999   Prof-specialty
# 550                 White    Male  United-States   17030  Exec-managerial
# 3096                White  Female  United-States   79670  Exec-managerial
# 1731                White  Female  United-States    6041            Sales
# 2618                White  Female  United-States   41646            Sales
# 2525                White    Male  United-States   11000     Adm-clerical
# 1642                White  Female        Ireland   24000     Craft-repair
# 3230                White  Female  United-States   17985    Other-service
# 1985   Asian-Pac-Islander    Male         Taiwan   99999  Exec-managerial
# 2698                Black  Female  United-States   13000     Adm-clerical
#
#        income-category
# index
# 2334                 2
# 550                  0
# 3096                 2
# 1731                 0
# 2618                 1
# 2525                 0
# 1642                 1
# 3230                 0
# 1985                 2
# 2698                 0

# %% [markdown]
# ---
#
# ## **Comparing datasets**

# %%
#What is the difference in well educated set (want to explain) compared to under educated one (prototypes).
(w_comp_hu, s_comp_hu, _) = explainer.explain(well, under, M)
comp_hu_human_readable = whole_census[whole_census["education-num"] < 10].iloc[s_comp_hu]
comp_hu_human_readable
# Out:
#        hours-per-week  age  capital-gain  capital-loss         workclass  \
# index
# 4500               45   39             0             0           Private
# 580                12   90          2964             0  Self-emp-not-inc
# 261                64   21             0             0           Private
# 4060                3   19             0             0           Private
# 2069               99   51             0             0      Self-emp-inc
# 5294               40   41             0             0         Local-gov
# 2448               50   43             0             0           Private
# 5037               40   27             0             0       Federal-gov
# 4185               40   45             0             0  Self-emp-not-inc
# 4042               40   55             0          1887         State-gov
#
#       education  education-num         marital-status   relationship  \
# index
# 4500    HS-grad              9     Married-civ-spouse        Husband
# 580     HS-grad              9          Never-married  Not-in-family
# 261     HS-grad              9          Never-married  Not-in-family
# 4060    HS-grad              9          Never-married      Own-child
# 2069    HS-grad              9  Married-spouse-absent  Not-in-family
# 5294    HS-grad              9               Divorced      Unmarried
# 2448    HS-grad              9     Married-civ-spouse           Wife
# 5037    HS-grad              9          Never-married  Not-in-family
# 4185    HS-grad              9     Married-civ-spouse        Husband
# 4042    HS-grad              9     Married-civ-spouse           Wife
#
#                      race  gender native-country  income       occupation  \
# index
# 4500                White    Male  United-States   48351   Prof-specialty
# 580                 White    Male  United-States   18169  Exec-managerial
# 261                 White  Female  United-States    5902    Other-service
# 4060                White    Male  United-States    6900            Sales
# 2069                White    Male  United-States   50460  Exec-managerial
# 5294                White  Female  United-States   26346  Exec-managerial
# 2448                White  Female         Canada   72575     Adm-clerical
# 5037                Black  Female  United-States   18000     Adm-clerical
# 4185   Asian-Pac-Islander    Male          China   16426  Exec-managerial
# 4042                White  Female  United-States   67713     Tech-support
#
#        income-category
# index
# 4500                 1
# 580                  0
# 261                  0
# 4060                 0
# 2069                 2
# 5294                 1
# 2448                 2
# 5037                 0
# 4185                 0
# 4042                 2

# %% [markdown]
# # **Checking Model Inaccuracy**

# %%
MODEL_NAME = "under_educated"
TARGET_SET = "../01_data/test/well_educated_labels.csv"

# %%
import neural_network
model = neural_network.create_model(well)

model.load_weights("../03_models/"+MODEL_NAME+"/")

# %%
predictions = np.argmax(model.predict(well), axis=1)

# %% [markdown]
# ### Searching for a "big mistake"

# %%
target = np.loadtxt(TARGET_SET, delimiter=",")
target = np.argmax(target, axis=1)
diffs = np.abs(predictions - target)

#searching for a big mistake:
idx = 0
while (idx<len(diffs)) and (diffs[idx] < 2):
    idx += 1

# %%
comp_human_readable = whole_census[whole_census["education-num"] >= 13].iloc[idx]
print("predicted: %d\t actual: %d"%(predictions[idx], target[idx]))
comp_human_readable
# Out:
# predicted: 0	 actual: 2
# hours-per-week                     40
# age                                32
# capital-gain                        0
# capital-loss                        0
# workclass                     Private
# education                   Bachelors
# education-num                      13
# marital-status     Married-civ-spouse
# relationship                  Husband
# race                            White
# gender                           Male
# native-country          United-States
# income                          77700
# occupation            Exec-managerial
# income-category                     2
# Name: 38, dtype: object

# %% [markdown]
# ### Trying to explain the mistake

# %%
(w_comp, s_comp, _) = explainer.explain(np.array(well[idx]).reshape(1,len(well[idx])), under, M)
comp_human_readable = whole_census[whole_census["education-num"] < 10].iloc[s_comp]
comp_human_readable
# Out:
#        hours-per-week  age  capital-gain  capital-loss         workclass  \
# index
# 4497               40   33             0             0           Private
# 5182               35   20             0             0           Private
# 3666               98   26             0             0      Self-emp-inc
# 3106                5   32             0             0  Self-emp-not-inc
# 1341               40   35             0             0         State-gov
# 559                40   18             0             0           Private
# 776                21   56             0             0      Self-emp-inc
# 5189               40   32             0             0           Private
# 1740               60   27             0             0  Self-emp-not-inc
# 4488               45   24             0             0           Private
#
#       education  education-num         marital-status    relationship  \
# index
# 4497    HS-grad              9     Married-civ-spouse         Husband
# 5182    HS-grad              9          Never-married   Not-in-family
# 3666       12th              8     Married-civ-spouse         Husband
# 3106    HS-grad              9     Married-civ-spouse            Wife
# 1341    HS-grad              9               Divorced       Unmarried
# 559     HS-grad              9          Never-married       Own-child
# 776     HS-grad              9     Married-civ-spouse  Other-relative
# 5189    HS-grad              9  Married-spouse-absent  Other-relative
# 1740    HS-grad              9     Married-civ-spouse         Husband
# 4488    HS-grad              9     Married-civ-spouse            Wife
#
#                      race  gender              native-country  income  \
# index
# 4497                White    Male               United-States   40200
# 5182                Black  Female  Outlying-US(Guam-USVI-etc)    7560
# 3666                Other    Male          Dominican-Republic   15500
# 3106                White  Female                           ?    2962
# 1341                White  Female               United-States   33000
# 559    Asian-Pac-Islander  Female               United-States    3025
# 776    Asian-Pac-Islander  Female                       China   20088
# 5189                Other    Male                      Mexico    6600
# 1740                White    Male                     Ireland   75050
# 4488   Amer-Indian-Eskimo  Female               United-States   21000
#
#             occupation  income-category
# index
# 4497   Exec-managerial                1
# 5182      Adm-clerical                0
# 3666             Sales                0
# 3106     Other-service                0
# 1341   Protective-serv                1
# 559              Sales                0
# 776    Exec-managerial                1
# 5189     Other-service                0
# 1740      Craft-repair                2
# 4488   Exec-managerial                1

# %%
w_comp = np.around(w_comp/np.sum(w_comp), 2)
w_comp
# Out:
# array([0.9 , 0.02, 0.01, 0.01, 0.02, 0.01, 0.01, 0.01, 0.01, 0.01])
